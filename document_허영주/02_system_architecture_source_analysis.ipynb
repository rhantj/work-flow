# %% [markdown]
# # WorkFlow AI 시스템 설계 소스 분석
#
# ## 목표
# 병합된 `feature/kanban` 소스를 기준으로 PPT 4.1~4.3의 근거와 발표 문안을 정리한다.
#
# ## 실행 플랜
# 1. React, Spring Boot, FastAPI, Docker, OCI/CI/CD 파일을 식별한다.
# 2. SQL 스키마와 JPA 엔티티를 교차 검증해 ERD와 주요 테이블을 정리한다.
# 3. Controller/Router 경로를 수집해 API 및 Swagger 구조를 정리한다.
# 4. 회의록 AI → To-Do → 업무보드 흐름을 프론트/백엔드/DB 코드로 추적한다.
# 5. RAG, 지연 위험도, 업무 편중, 기여도 계산 로직을 실제 수식과 함께 정리한다.
# 6. 결과를 `document_허영주/output/system_architecture_ppt/`와 `document_허영주/`에 저장한다.

# %%
# 소스 인벤토리 재현용 예시
# !rg --files App docs .github
# !rg '@(Get|Post|Put|Patch|Delete)Mapping|APIRouter|include_router' App/backend_spring App/backend_fastapi

# %% [markdown]
# ## 분석 결과
# - React–Spring Boot–FastAPI–PostgreSQL/pgvector의 역할 분리 구조를 확인했다.
# - 회의록 분석은 비동기 처리되며 AI To-Do 후보 승인 후 `tasks`에 등록된다.
# - OCI CD·health check·rollback은 구현되어 있고 별도 PR CI workflow는 확인되지 않았다.
# - 지연위험도, 업무 편중, 기여도 계산식을 실제 서비스 코드에서 확인했다.
#
# ## 산출물
# - PPT용 상세 원고: `document_허영주/2026-07-21-system-architecture-ppt-content.md`
# - 15장 HTML/CSS 슬라이드: `document_허영주/output/system_architecture_ppt/index.html`
# - 소스 근거 30건: `document_허영주/output/system_architecture_ppt/source_evidence.csv`
