# %% [markdown]
# # 프로젝트 알림 고위험 피드백 후속 조치
#
# ## 실행 계획
# 1. 현재 브랜치와 체크리스트 자동 상태 이동 호출 경로를 재확인한다.
# 2. 소속 프로젝트 수를 이용한 과거 `NULL project_id` 역산을 제거한다.
# 3. 프론트엔드에서 동일 업무·상태 이동 요청이 진행 중이면 후속 중복 요청을 차단한다.
# 4. 백엔드에서 업무 행을 잠근 뒤 상태를 비교해 동시 요청의 중복 알림을 차단한다.
# 5. 프론트·백엔드 회귀 테스트와 빌드를 실행한다.

# %% [markdown]
# ## 진행 상태
#
# - [x] 위험한 소속 기반 역산 제거
# - [x] 프론트 중복 요청 방지
# - [x] 백엔드 동시 요청 방어
# - [x] 회귀 테스트 및 빌드
#
# ### 검증 결과
#
# - 백엔드 알림 및 `TaskControllerPositionTest`: 성공
# - 프론트 상태 이동·체크리스트·알림 29개 테스트: 성공
# - 프론트 Vite 프로덕션 빌드: 성공
